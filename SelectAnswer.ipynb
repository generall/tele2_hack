# %%
# %%bash
# QUESTION='Здравствуйте, как обменять минуты на гигобайты?'
#
# cat ./data/clustered_answers.txt | xargs -I {} echo $QUESTION$'\t'{} > ./data/question_match.tsv
#
# cd DSSM;
# python predict_tele2.py --model ../data/Matcher_best_clear.pth\
#                            --mtx-path ../data/ft_vect.dat\
#                            --meta-path ../data/ft_meta.json\
#                            --input-file ../data/question_match.tsv | tail -n +4 > ../data/question_match_score.txt
#
# cd ..
#
# paste ./data/question_match_score.txt ./data/clustered_answers.txt | sort -nrk 1 | head -n 5
# Out:
# 0.9364514946937561	Здравствуйте U 0001F60A С удовольствием U 0001F60A Произвести обмен можно по команде 155 62 кол во минут для обмена вызов Также вся подробная информация об услуге Меняйте минуты на Гб представлена по ссылке https vologda tele2 ru exchange Еще помогу U 0001F60A
# 0.9143386483192444	Здравствуйте Можете воспользоваться услугой Меняйте минуты на ГБ по команде 155 62 количество минут для обмена вызов 100 минут 1 ГБ 10 минут 102 4 МБ 1 минута 10 24 МБ Объем интернет трафика полученный в обмен на минуты на следующий расчетный период не переносится Перенос остатков осуществляется только из основного пакета Подробности об услуге включая доступность на нашем сайте https tele2 ru exchange
# ...

# %%
# %%bash
# QUESTION='Здравствуйте, как купить диван?'
#
# cat ./data/clustered_answers.txt | xargs -I {} echo $QUESTION$'\t'{} > ./data/question_match.tsv
#
# cd DSSM;
# python predict_tele2.py --model ../data/Matcher_best_clear.pth\
#                            --mtx-path ../data/ft_vect.dat\
#                            --meta-path ../data/ft_meta.json\
#                            --input-file ../data/question_match.tsv | tail -n +4 > ../data/question_match_score.txt
#
# cd ..
#
# paste ./data/question_match_score.txt ./data/clustered_answers.txt | sort -nrk 1 | head -n 5
# Out:
# 0.27447274327278137	Здравствуйте На тарифе Мой онлайн уже включен безлимит на социальные сети и мессенджеры Без расходования интернет трафика включенного в тариф абоненту предоставляется доступ к социальным сетям ВКонтакте Одноклассники Facebook через браузер телефона и официальные приложения а также к мессенджерам WhatsApp и Viber Расходование пакета интернета включенного в тариф происходит если через приложение или сайт ВКонтакте Одноклассники Facebook открываются страницы с
# 0.25184163451194763	Здравствуйте U 0001F60A согласно тарифу Мой Tele2 интернет трафик не будет расходоваться из пакета при раздаче интернета по Wi Fi если пользователи подключенные к Wi Fi будут посещать социальные сети ВКонтакте Одноклассники Facebook VK Live и мессенджеры WhatsApp Viber и xxxxx xxxxx xxxxx Подробнее о тарифе параметры стоимость способы управления на нашем сайте https tele2 ru tariff my tele2 Возможно еще остались вопросы у вас
# ...

# %%
# %%bash
# QUESTION='У меня плохая всязь, интернет не ловит'
#
# cat ./data/clustered_answers.txt | xargs -I {} echo $QUESTION$'\t'{} > ./data/question_match.tsv
#
# cd DSSM;
# python predict_tele2.py --model ../data/Matcher_best_clear.pth\
#                            --mtx-path ../data/ft_vect.dat\
#                            --meta-path ../data/ft_meta.json\
#                            --input-file ../data/question_match.tsv | tail -n +4 > ../data/question_match_score.txt
#
# cd ..
#
# paste ./data/question_match_score.txt ./data/clustered_answers.txt | sort -nrk 1 | head -n 5
# Out:
# 0.6141725182533264	Здравствуйте Ситуация действительно вызывает неудобства Для решения сообщите нам в ЛС город улxxxxxxxxxxx3G H 4G LTE Если не тестировали скорость интернета то рекомендуем это сделать Протестировать можно здесь http www speedtest net ru Результат пришлите Можно в виде скриншота
# 0.5996106266975403	Здравствуйте Скорость передачи данных зависит от уровня сигнала чем ниже сигнал тем меньше скорость удаленности от базовой станции абонентского оборудования отсутствие поддержки HSPA загруженности базовой станции плотности застройки Если у вас низкая скорость рекомендуем очистить кэш память браузера и приложений удалить Cookies перезагрузить устройство и повторить попытку Возможно есть еще вопросы
# 0.5847604274749756	Здравствуйте Связь отсутствует только внутри помещений Данная ситуация наблюдается по определенным адресам В настройках вашего телефона установлен смешанный режим сети Вы тестировали SIM карту в другом телефоне
# ...
